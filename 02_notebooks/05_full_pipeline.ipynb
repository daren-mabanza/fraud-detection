# %% [markdown]
# # Paramétrage de l'environnement de travail et import des packages

# %%
import sys
from pathlib import Path

# %%
ROOT = Path.cwd().parents[0]

RAW_DATA = ROOT / "01_data" / "01_raw"
PROCESSED_DATA = ROOT / "01_data" / "02_processed"

# %load_ext autoreload
# %autoreload 2
sys.path.append(str(ROOT / "03_fonctions"))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
from script_complet.full_pipeline import full_fraud_detection_projet

# %% [markdown]
# # La base de données

# %%
data_fraud = pd.read_parquet(PROCESSED_DATA / "data_fraud_eda_processed.parquet").reset_index(drop = True)

# %% [markdown]
# **Informations globales**

# %%
data_fraud.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1852394 entries, 0 to 1852393
# Data columns (total 19 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   nom_magasin                object
#  1   type_magasin               object
#  2   montant_transaction        float64
#  3   ville_client               object
#  4   etat_client                object
#  5   latitude_domicile_client   float64
#  6   longitude_domicile_client  float64
#  7   population_ville_client    int64
#  8   profession_client          object
#  9   numero_transaction         object
#  10  latitude_magasin           float64
#  11  longitude_magasin          float64
#  12  target                     int64
#  13  annee_transaction          int32
#  14  mois_transaction           object
#  15  jour_transaction           object
#  16  heure_transaction          int32
#  17  distance_domicile_magasin  float64
#  18  age_client                 int32
# dtypes: float64(6), int32(3), int64(2), object(8)
# memory usage: 247.3+ MB

# %% [markdown]
# **Statistiques descriptives**

# %%
data_fraud.describe()
# Out:
#        montant_transaction  latitude_domicile_client  \
# count         1.852394e+06              1.852394e+06
# mean          7.006357e+01              3.853931e+01
# std           1.592540e+02              5.071470e+00
# min           1.000000e+00              2.002710e+01
# 25%           9.640000e+00              3.466890e+01
# 50%           4.745000e+01              3.935430e+01
# 75%           8.310000e+01              4.194040e+01
# max           2.894890e+04              6.669330e+01
#
#        longitude_domicile_client  population_ville_client  latitude_magasin  \
# count               1.852394e+06             1.852394e+06      1.852394e+06
# mean               -9.022783e+01             8.864367e+04      3.853898e+01
# std                 1.374789e+01             3.014876e+05      5.105604e+00
# min                -1.656723e+02             2.300000e+01      1.902742e+01
# 25%                -9.679800e+01             7.410000e+02      3.474012e+01
# 50%                -8.747690e+01             2.443000e+03      3.936890e+01
# 75%                -8.015800e+01             2.032800e+04      4.195626e+01
# max                -6.795030e+01             2.906700e+06      6.751027e+01
#
#        longitude_magasin        target  annee_transaction  heure_transaction  \
# count       1.852394e+06  1.852394e+06       1.852394e+06       1.852394e+06
# mean       -9.022794e+01  5.210015e-03       2.019501e+03       1.280612e+01
# std         1.375969e+01  7.199217e-02       4.999996e-01       6.815753e+00
# min        -1.666716e+02  0.000000e+00       2.019000e+03       0.000000e+00
# 25%        -9.689944e+01  0.000000e+00       2.019000e+03       7.000000e+00
# 50%        -8.744069e+01  0.000000e+00       2.020000e+03       1.400000e+01
# 75%        -8.024511e+01  0.000000e+00       2.020000e+03       1.900000e+01
# max        -6.695090e+01  1.000000e+00       2.020000e+03       2.300000e+01
#
#        distance_domicile_magasin    age_client
# count               1.852394e+06  1.852394e+06
# mean                7.611183e+01  4.621138e+01
# std                 2.911701e+01  1.739545e+01
# min                 2.225455e-02  1.400000e+01
# 25%                 5.532016e+01  3.300000e+01
# 50%                 7.821649e+01  4.400000e+01
# 75%                 9.850960e+01  5.700000e+01
# max                 1.521174e+02  9.600000e+01

# %% [markdown]
# **Aperçu rapide des données**

# %%
data_fraud.head()
# Out:
#                       nom_magasin    type_magasin  montant_transaction  \
# 0                 Kirlin and Sons   personal_care                 2.86
# 1                  Sporer-Keebler   personal_care                29.84
# 2  Swaniawski, Nitzsche and Welch  health_fitness                41.28
# 3                     Haley Group        misc_pos                60.05
# 4                 Johnston-Casper          travel                 3.19
#
#   ville_client etat_client  latitude_domicile_client  \
# 0     Columbia          SC                   33.9659
# 1      Altonah          UT                   40.3207
# 2     Bellmore          NY                   40.6729
# 3   Titusville          FL                   28.5697
# 4     Falmouth          MI                   44.2529
#
#    longitude_domicile_client  population_ville_client       profession_client  \
# 0                   -80.9355                   333497     Mechanical engineer
# 1                  -110.4360                      302  Sales professional, IT
# 2                   -73.5365                    34496       Librarian, public
# 3                   -80.8191                    54767            Set designer
# 4                   -85.0170                     1126      Furniture designer
#
#                  numero_transaction  latitude_magasin  longitude_magasin  \
# 0  2da90c7d74bd46a0caf3777415b3ebd3         33.986391         -81.200714
# 1  324cc204407e99f51b0d6ca0055005e7         39.450498        -109.960431
# 2  c81755dbbbea9d5c77f094348a7579be         40.495810         -74.196111
# 3  2159175b9efe66dc301f149d3d5abf8c         28.812398         -80.883061
# 4  57ff021bd3f328f8738bb535c302a31b         44.959148         -85.884734
#
#    target  annee_transaction mois_transaction jour_transaction  \
# 0       0               2020             June           Sunday
# 1       0               2020             June           Sunday
# 2       0               2020             June           Sunday
# 3       0               2020             June           Sunday
# 4       0               2020             June           Sunday
#
#    heure_transaction  distance_domicile_magasin  age_client
# 0                 12                  24.561496          52
# 1                 12                 104.925237          30
# 2                 12                  59.080159          50
# 3                 12                  27.698606          33
# 4                 12                 104.335250          65

# %% [markdown]
# # Pipeline complète du projet

# %%
full_fraud_detection_projet()

# %% [markdown]
# # Note explicative du Notebook
